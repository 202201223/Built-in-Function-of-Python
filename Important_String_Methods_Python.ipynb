# %% [markdown]
# ![634806851af115b83384e8240a726df8.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Upper Function**
# Build in function for string used to capitalized all character of string in python

# %%
word = 'hellow world'
print(word.upper())
# Out:
# HELLOW WORLD

# %% [markdown]
# # **Istrip Function**
# Build in function for string used to remove all spaces of string and can remove a spacific char from the string

# %%
word = "  mariam"
print("my name is",word.strip())
# Out:
# my name is mariam

# %% [markdown]
# # **rfind function**
# build in function used to serach for a spacific value in its last occurance and return -1 if it is not found

# %%
sentenc = "this is my bag,the bag is too long"
print(sentenc.rfind("bag"))
# Out:
# 19

# %% [markdown]
# # **replace function**
# build in function for string used for replace a word with another one

# %%
sentence = "the lovly fruits are apple and mango"
print(sentence.replace("apple","orange"))
# Out:
# the lovly fruits are orange and mango

# %% [markdown]
# # **rsplit function**
# build in function for string used to split the string into list of string

# %%
text = "october,novamber,decamber"
print(text.rsplit(","))
# Out:
# ['october', 'novamber', 'decamber']

# %% [markdown]
# ## Split Function
# build in function use to convert the string to any data type as list as it works on spliting the string by see the whitespaces and split the iteam that befor it by using a comma

# %%
myString = "This is me mariam"
print(myString.split())
# Out:
# ['This', 'is', 'me', 'mariam']

# %% [markdown]
# # **Start with function**
# build in function that take an argumant and check if it is the start point to the last string return true else return false

# %%
myString = "This is me mariam"
print(myString.startswith("This"))
# Out:
# True

# %% [markdown]
# # **Strip function**
# build in function use to delete the whitespaces from the string by defulte and it has the option to delete the character that we need to delete by write it as an argumant to the function

# %%
myString = "  me  "
modifide_string = myString.strip()
print("This is",modifide_string,"mariam")
# Out:
# This is me mariam

# %% [markdown]
# # **Title function**
# build in function that return the first charcater each word with in upper case formate

# %%
myString = "this is me mariam"
print(myString.title())
# Out:
# This Is Me Mariam

# %% [markdown]
# # **splitlines function**
# build in function that help in split the string if the  line breaks symbole.

# %%
myString = "This is me mariam\n studing in zewail city"
print(myString.splitlines())
# Out:
# ['This is me mariam', ' studing in zewail city']

# %% [markdown]
# Case Fold function
# this function return the string in lower case format

# %%
myString = "This Is Me Mariam"
print(myString.casefold())
# Out:
# this is me mariam

# %% [markdown]
# # **capitalize function**
# build in function that retrun the first charater of string in upper case and others in lower case

# %%
myString = "this Is me MAriam"
print(myString.capitalize())
# Out:
# This is me mariam

# %% [markdown]
# # **Center function**
# a build in function that return the string but in center align the string, using a specified character as the fill character, defulte value is one step

# %%
myString = "mariam"
print(myString.center(20))
# Out:
#        mariam

# %% [markdown]
# # **Count function**
# build in function that return how many does the given argumant appers in the string or list

# %%
myString = ["banana","mango","apply","banana"]
print(myString.count("banana"))
# Out:
# 2

# %% [markdown]
# # **encode function**
# build in function that return the encode string

# %%
myString = "mariam"
print(myString.encode())
# Out:
# b'mariam'

# %% [markdown]
# # end with function
# build in function that return true if the given argument end the string

# %%
myString = "This is me mariam"
print(myString.endswith("m"))
# Out:
# True

# %% [markdown]
# ## find function
# build in function that return -1 if the given argument is not in the string or return index if it occure in the string

# %%
myString = "This is me mariam"
print(myString.find("are"))   #will return -1
print(myString.find("me"))    #will return the index
# Out:
# -1
# 8

# %% [markdown]
# # **Format Function**
# build in function that take a spacific value and format it then isert it in the string inside the placeholder

# %%
myString = "my age is {age:f}"
print(myString.format(age = 19))
# Out:
# my age is 19.000000

# %% [markdown]
# # **index function**
# build in function that return the index of first occurance in the list or string

# %%
myString = ["banana","mango","apply","banana"]
print(myString.index("banana"))
# Out:
# 0

# %% [markdown]
# # **isalnum function**
# build in function that return true if the string has an alphabet characters and numbers only

# %%
myString = "mariam19"
print(myString.isalnum())
# Out:
# True

# %% [markdown]
# # **isalpha function**
# build in function that return true if the string has an alphabet characters only

# %%
myString = "mariam19"
print(myString.isalpha())   # will return false as it has a numarical value
# Out:
# False

# %% [markdown]
# # **isdecimal function**
# build in function that return true if the string has an decimal numbers only(0-9)

# %%
myString = "12"
print(myString.isdecimal())
# Out:
# True

# %% [markdown]
# # **isdigit function**
# build in function that return true if the string has an digit numbers

# %%
myString = "12"
print(myString.isdigit())
# Out:
# True

# %% [markdown]
# # **isidentifier function**
# build in function that return true if the string contain a valid function that consider an alphate letter or number or underscore other wise retirn false

# %%
myString = "mariam_19"
print(myString.isidentifier())
# Out:
# True

# %% [markdown]
# # **islower function**
# build in function that return true if all characters are in lower case format

# %%
myString = "this is me mariam"
print(myString.islower())
# Out:
# True

# %% [markdown]
# # **isnumeric function**
# build in function that return true if all characters are numbers(0-9)

# %%
myString = "19"
print(myString.isnumeric())
# Out:
# True

# %% [markdown]
# # **isspace function**
# build in function that return true if all characters are whitespaces

# %%
myString = " "
print(myString.isspace())
# Out:
# True

# %% [markdown]
# # **istitle function**
# build in function that return true if first character of each word in the text is in upper case formate and other are lower

# %%
myString = "This Is Me Mariam"
print(myString.istitle())
# Out:
# True

# %% [markdown]
# # **isprinttable function**
# build in function returns True if all the characters are printable, otherwise False

# %%
myString = "This Is Me Mariam"
print(myString.isprintable())
# Out:
# True

# %% [markdown]
# # **isupper function**
# build in function return true that all character are in upper case format

# %%
myString = "THIS IS ME MARIAM"
print(myString.isupper())
# Out:
# True

# %% [markdown]
# # **join function**
# build in function is to take the string itemas in separbable form and strat to join theam using the given item

# %%
myString = ("banana","mango","apply","banana")
print("^".join(myString))
# Out:
# banana^mango^apply^banana

# %% [markdown]
# # **lower function**
# return all text in lower case format

# %%
myString = "THIS IS ME MARIAM"
print(myString.lower())
# Out:
# this is me mariam
