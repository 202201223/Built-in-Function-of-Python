# %% [markdown]
# ![0815C073-BCBF-4DDD-9067-FB8FF1AA551D.jpg](data:image/jpeg;base64,...)

# %%
# int function
x = 5.5
print(int(x))    #take the float number which is 5.5 and convert it into 5 which is integer
# Out:
# 5

# %%
# float function
x = 5
print(float(x))   #take the number int which is 5 and convert it into 5.0 which is floating number
# Out:
# 5.0

# %%
# absolute function
x = -5
print(abs(x))   #take the negative number which is -5 and convert it into positive number which 5
# Out:
# 5

# %%
# cmp function --->was defined in python 2 but has no defintion in python 3
#cmp(4,5)  will return -1 as x<y
#cmp(5,4)  will return 1 as x>y
#cmp(5,5)  will return 0 as x=y

# %%
# sqrt function
#need to import math modul to apply sqrt function
from math import sqrt
x = 25
sqrt(x)  #will return the result of square root of 25 which is 5
# Out:
# 5.0

# %%
#log function
#need to import math modul to apply log function
from math import log
x = 2
log(x)  #will return the result of log 2
# Out:
# 0.6931471805599453

# %%
# power function
x = 5 #the first number which is base
y = 2 #the second which is exponent
print(pow(5,2))
# Out:
# 25
